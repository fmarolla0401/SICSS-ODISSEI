# %%
# !pip show pandas
# Out:
# Name: pandas
# Version: 1.5.3
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: c:\users\fmarolla\appdata\local\anaconda3\lib\site-packages
# Requires: numpy, python-dateutil, pytz
# Required-by: datashader, holoviews, hvplot, seaborn, statsmodels, xarray

# %%
import pandas as pd

# %%
file_path = "C:/Users/fmarolla/OneDrive - Tilburg University/Bureaublad/Backup/data_subsample.csv"

# %%
data = pd.read_csv(file_path)

# %%
# !pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(file_path)

# %%
column_data = data['cf19l393'].dropna()

# %%
plt.hist(column_data, bins=50, edgecolor='black', color='#6c8dc6', alpha=0.7)
plt.xlabel('cf19l393')
plt.ylabel('Frequency')
plt.title('Histogram of cf19l393')
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.tight_layout()
plt.show()
